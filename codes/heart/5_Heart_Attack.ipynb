# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/5. heart.csv')
data.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
data.shape
# Out:
# (918, 12)

# %%
data.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
data.describe().T
# Out:
#               count        mean         std   min     25%    50%    75%    max
# Age           918.0   53.510893    9.432617  28.0   47.00   54.0   60.0   77.0
# RestingBP     918.0  132.396514   18.514154   0.0  120.00  130.0  140.0  200.0
# Cholesterol   918.0  198.799564  109.384145   0.0  173.25  223.0  267.0  603.0
# FastingBS     918.0    0.233115    0.423046   0.0    0.00    0.0    0.0    1.0
# MaxHR         918.0  136.809368   25.460334  60.0  120.00  138.0  156.0  202.0
# Oldpeak       918.0    0.887364    1.066570  -2.6    0.00    0.6    1.5    6.2
# HeartDisease  918.0    0.553377    0.497414   0.0    0.00    1.0    1.0    1.0

# %% [markdown]
# EDA

# %%
col = list(data.columns)
categorical_features = []
numerical_features = []
for i in col:
    if len(data[i].unique()) > 6:
        numerical_features.append(i)
    else:
        categorical_features.append(i)

print('Categorical Features :',*categorical_features)
print('Numerical Features :',*numerical_features)
# Out:
# Categorical Features : Sex ChestPainType FastingBS RestingECG ExerciseAngina ST_Slope HeartDisease
# Numerical Features : Age RestingBP Cholesterol MaxHR Oldpeak

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df1 = data.copy(deep = True)

df1['Sex'] = le.fit_transform(df1['Sex'])
df1['ChestPainType'] = le.fit_transform(df1['ChestPainType'])
df1['RestingECG'] = le.fit_transform(df1['RestingECG'])
df1['ExerciseAngina'] = le.fit_transform(df1['ExerciseAngina'])
df1['ST_Slope'] = le.fit_transform(df1['ST_Slope'])

# %%
colors = ['#F93822','#FDD20E']
fig, ax = plt.subplots(nrows = 3,ncols = 2,figsize = (10,15))
for i in range(len(categorical_features) - 1):

    plt.subplot(3,2,i+1)
    sns.distplot(df1[categorical_features[i]],kde_kws = {'bw' : 1},color = colors[0]);
    title = 'Distribution : ' + categorical_features[i]
    plt.title(title)

plt.figure(figsize = (4.75,4.55))
sns.distplot(df1[categorical_features[len(categorical_features) - 1]],kde_kws = {'bw' : 1},color = colors[0])
title = 'Distribution : ' + categorical_features[len(categorical_features) - 1]
plt.title(title);
# Out:
# <ipython-input-14-7336c3dc1ebc>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1[categorical_features[i]],kde_kws = {'bw' : 1},color = colors[0]);
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:2496: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=1`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.14.0.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# <ipython-input-14-7336c3dc1ebc>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1[categorical_features[i]],kde_kws = {'bw' : 1},color = colors[0]);
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:2496: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=1`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.14.0.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# <ipython-input-14-7336c3dc1ebc>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1[categorical_features[i]],kde_kws = {'bw' : 1},color = colors[0]);
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:2496: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=1`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.14.0.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# <ipython-input-14-7336c3dc1ebc>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1[categorical_features[i]],kde_kws = {'bw' : 1},color = colors[0]);
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:2496: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=1`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.14.0.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# <ipython-input-14-7336c3dc1ebc>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1[categorical_features[i]],kde_kws = {'bw' : 1},color = colors[0]);
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:2496: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=1`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.14.0.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# <ipython-input-14-7336c3dc1ebc>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1[categorical_features[i]],kde_kws = {'bw' : 1},color = colors[0]);
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:2496: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=1`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.14.0.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# <ipython-input-14-7336c3dc1ebc>:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1[categorical_features[len(categorical_features) - 1]],kde_kws = {'bw' : 1},color = colors[0])
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:2496: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=1`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.14.0.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %%
fig, ax = plt.subplots(nrows = 2,ncols = 2,figsize = (10,9.75))
for i in range(len(numerical_features) - 1):
    plt.subplot(2,2,i+1)
    sns.distplot(data[numerical_features[i]],color = colors[0])
    title = 'Distribution : ' + numerical_features[i]
    plt.title(title)
plt.show()

plt.figure(figsize = (4.75,4.55))
sns.distplot(df1[numerical_features[len(numerical_features) - 1]],kde_kws = {'bw' : 1},color = colors[0])
title = 'Distribution : ' + numerical_features[len(numerical_features) - 1]
plt.title(title);
# Out:
# <ipython-input-15-ecbaa2f42566>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[numerical_features[i]],color = colors[0])
# <ipython-input-15-ecbaa2f42566>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[numerical_features[i]],color = colors[0])
# <ipython-input-15-ecbaa2f42566>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[numerical_features[i]],color = colors[0])
# <ipython-input-15-ecbaa2f42566>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[numerical_features[i]],color = colors[0])
# <ipython-input-15-ecbaa2f42566>:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1[numerical_features[len(numerical_features) - 1]],kde_kws = {'bw' : 1},color = colors[0])
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:2496: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=1`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.14.0.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %%
l = list(data['HeartDisease'].value_counts())
circle = [l[1] / sum(l) * 100,l[0] / sum(l) * 100]

plt.pie(circle,labels = ['No Heart Disease','Heart Disease'],autopct='%1.1f%%',startangle = 90,explode = (0.1,0),colors = colors,
        wedgeprops = {'edgecolor' : 'black','linewidth': 1,'antialiased' : True})
plt.title('Heart Disease %');

plt.show()

# %%
sex = data[data['HeartDisease'] == 1]['Sex'].value_counts()
sex = [sex[0] / sum(sex) * 100, sex[1] / sum(sex) * 100]

cp = data[data['HeartDisease'] == 1]['ChestPainType'].value_counts()
cp = [cp[0] / sum(cp) * 100,cp[1] / sum(cp) * 100,cp[2] / sum(cp) * 100,cp[3] / sum(cp) * 100]

fbs = data[data['HeartDisease'] == 1]['FastingBS'].value_counts()
fbs = [fbs[0] / sum(fbs) * 100,fbs[1] / sum(fbs) * 100]

restecg = data[data['HeartDisease'] == 1]['RestingECG'].value_counts()
restecg = [restecg[0] / sum(restecg) * 100,restecg[1] / sum(restecg) * 100,restecg[2] / sum(restecg) * 100]

exang = data[data['HeartDisease'] == 1]['ExerciseAngina'].value_counts()
exang = [exang[0] / sum(exang) * 100,exang[1] / sum(exang) * 100]

slope = data[data['HeartDisease'] == 1]['ST_Slope'].value_counts()
slope = [slope[0] / sum(slope) * 100,slope[1] / sum(slope) * 100,slope[2] / sum(slope) * 100]

# %%
#converting numerical features to categorical features to
data['RestingBP_Group'] = [ int(i / 5) for i in data['RestingBP']]
data['Cholesterol_Group'] = [ int(i / 10) for i in data['Cholesterol']]
data['MaxHR_Group'] = [ int(i / 5) for i in data['MaxHR']]
data['Oldpeak_Group'] = [ int( (i*10) / 5) for i in data['Oldpeak']]

# %%
data.corr()["HeartDisease"].abs().sort_values(ascending=False)
# Out:
# <ipython-input-27-20b312c150c5>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()["HeartDisease"].abs().sort_values(ascending=False)
# HeartDisease         1.000000
# Oldpeak_Group        0.407399
# Oldpeak              0.403951
# MaxHR                0.400421
# MaxHR_Group          0.400361
# Age                  0.282039
# FastingBS            0.267291
# Cholesterol          0.232741
# Cholesterol_Group    0.231673
# RestingBP            0.107589
# RestingBP_Group      0.105206
# Name: HeartDisease, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler
mms = MinMaxScaler() # Normalization
ss = StandardScaler() # Standardization

df1['Oldpeak'] = mms.fit_transform(df1[['Oldpeak']])
df1['Age'] = ss.fit_transform(df1[['Age']])
df1['RestingBP'] = ss.fit_transform(df1[['RestingBP']])
df1['Cholesterol'] = ss.fit_transform(df1[['Cholesterol']])
df1['MaxHR'] = ss.fit_transform(df1[['MaxHR']])
df1.head()
# Out:
#         Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  \
# 0 -1.433140    1              1   0.410909     0.825070          0
# 1 -0.478484    0              2   1.491752    -0.171961          0
# 2 -1.751359    1              1  -0.129513     0.770188          0
# 3 -0.584556    0              0   0.302825     0.139040          0
# 4  0.051881    1              2   0.951331    -0.034755          0
#
#    RestingECG     MaxHR  ExerciseAngina   Oldpeak  ST_Slope  HeartDisease
# 0           1  1.382928               0  0.295455         2             0
# 1           1  0.754157               0  0.409091         1             1
# 2           2 -1.525138               0  0.295455         2             0
# 3           1 -1.132156               1  0.465909         1             1
# 4           1 -0.581981               0  0.295455         2             0

# %%
corr = df1.corrwith(df1['HeartDisease']).sort_values(ascending = False).to_frame()
corr.columns = ['Correlations']
plt.subplots(figsize = (5,5))
sns.heatmap(corr,annot = True,cmap = colors,linewidths = 0.4,linecolor = 'black');
plt.title('Correlation w.r.t HeartDisease');

# %%
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

features = df1.loc[:,numerical_features]
target = df1.loc[:,categorical_features[-1]]

best_features = SelectKBest(score_func = f_classif,k = 'all')
fit = best_features.fit(features,target)

featureScores = pd.DataFrame(data = fit.scores_,index = list(features.columns),columns = ['ANOVA Score'])

plt.subplots(figsize = (5,5))
sns.heatmap(featureScores.sort_values(ascending = False,by = 'ANOVA Score'),annot = True,cmap = colors,linewidths = 0.4,linecolor = 'black',fmt = '.2f');
plt.title('Selection of Numerical Features');

# %%
features = df1.loc[:,categorical_features[:-1]]
target = df1.loc[:,categorical_features[-1]]

best_features = SelectKBest(score_func = chi2,k = 'all')
fit = best_features.fit(features,target)

featureScores = pd.DataFrame(data = fit.scores_,index = list(features.columns),columns = ['Chi Squared Score'])

plt.subplots(figsize = (5,5))
sns.heatmap(featureScores.sort_values(ascending = False,by = 'Chi Squared Score'),annot = True,cmap = colors,linewidths = 0.4,linecolor = 'black',fmt = '.2f');
plt.title('Selection of Categorical Features');

# %% [markdown]
# Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import RocCurveDisplay
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import precision_recall_curve

# %%
features = df1[df1.columns.drop(['HeartDisease','RestingBP','RestingECG'])].values
target = df1['HeartDisease'].values
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size = 0.20, random_state = 2)

# %%
def model(classifier):

    classifier.fit(x_train,y_train)
    prediction = classifier.predict(x_test)
    cv = RepeatedStratifiedKFold(n_splits = 10,n_repeats = 3,random_state = 1)
    print("Accuracy : ",'{0:.2%}'.format(accuracy_score(y_test,prediction)))
    print("Cross Validation Score : ",'{0:.2%}'.format(cross_val_score(classifier,x_train,y_train,cv = cv,scoring = 'roc_auc').mean()))
    print("ROC_AUC Score : ",'{0:.2%}'.format(roc_auc_score(y_test,prediction)))
    RocCurveDisplay.from_estimator(classifier, x_test,y_test)
    plt.title('ROC_AUC_Plot')
    plt.show()

def model_evaluation(classifier):

    # Confusion Matrix
    cm = confusion_matrix(y_test,classifier.predict(x_test))
    names = ['True Neg','False Pos','False Neg','True Pos']
    counts = [value for value in cm.flatten()]
    percentages = ['{0:.2%}'.format(value) for value in cm.flatten()/np.sum(cm)]
    labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(names,counts,percentages)]
    labels = np.asarray(labels).reshape(2,2)
    sns.heatmap(cm,annot = labels,cmap = colors,fmt ='')

    # Classification Report
    print(classification_report(y_test,classifier.predict(x_test)))

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

classifier_lr = LogisticRegression(random_state = 0,C=10,penalty= 'l2')
model(classifier_lr)
# Out:
# Accuracy :  87.50%
# Cross Validation Score :  91.12%
# ROC_AUC Score :  87.43%

# %%
model_evaluation(classifier_lr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.87        89
#            1       0.87      0.89      0.88        95
#
#     accuracy                           0.88       184
#    macro avg       0.88      0.87      0.87       184
# weighted avg       0.88      0.88      0.87       184

# %% [markdown]
# SVM

# %%
from sklearn.svm import SVC

classifier_svc = SVC(kernel = 'linear', C = 0.1, probability=True)
model(classifier_svc)
# Out:
# Accuracy :  87.50%
# Cross Validation Score :  90.53%
# ROC_AUC Score :  87.43%

# %%
model_evaluation(classifier_svc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.87        89
#            1       0.87      0.89      0.88        95
#
#     accuracy                           0.88       184
#    macro avg       0.88      0.87      0.87       184
# weighted avg       0.88      0.88      0.87       184

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

classifier_dt = DecisionTreeClassifier(random_state = 1000,max_depth = 4,min_samples_leaf = 1)
model(classifier_dt)
# Out:
# Accuracy :  84.78%
# Cross Validation Score :  89.09%
# ROC_AUC Score :  84.62%

# %%
model_evaluation(classifier_dt)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.80      0.84        89
#            1       0.83      0.89      0.86        95
#
#     accuracy                           0.85       184
#    macro avg       0.85      0.85      0.85       184
# weighted avg       0.85      0.85      0.85       184

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

classifier_rf = RandomForestClassifier(max_depth = 4,random_state = 0)
model(classifier_rf)
# Out:
# Accuracy :  84.24%
# Cross Validation Score :  92.91%
# ROC_AUC Score :  84.06%

# %%
model_evaluation(classifier_rf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.79      0.83        89
#            1       0.82      0.89      0.85        95
#
#     accuracy                           0.84       184
#    macro avg       0.85      0.84      0.84       184
# weighted avg       0.85      0.84      0.84       184

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

classifier_knn = KNeighborsClassifier(leaf_size = 1, n_neighbors = 3,p = 1)
model(classifier_knn)
# Out:
# Accuracy :  81.52%
# Cross Validation Score :  89.34%
# ROC_AUC Score :  81.36%

# %%
model_evaluation(classifier_knn)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.76      0.80        89
#            1       0.80      0.86      0.83        95
#
#     accuracy                           0.82       184
#    macro avg       0.82      0.81      0.81       184
# weighted avg       0.82      0.82      0.81       184

# %% [markdown]
# XGBoost

# %%
import xgboost as xgb

xgb = xgb.XGBClassifier(objective='binary:logistic')
model(xgb)
# Out:
# Accuracy :  84.78%
# Cross Validation Score :  91.91%
# ROC_AUC Score :  84.66%

# %%
model_evaluation(xgb)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.81      0.84        89
#            1       0.83      0.88      0.86        95
#
#     accuracy                           0.85       184
#    macro avg       0.85      0.85      0.85       184
# weighted avg       0.85      0.85      0.85       184

# %% [markdown]
# CatBoost

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.3-cp310-cp310-manylinux2014_x86_64.whl (98.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.5/98.5 MB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.25.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.3

# %%
from catboost import CatBoostClassifier

clf = CatBoostClassifier(
    iterations=30,
    learning_rate=0.5,
    #loss_function='CrossEntropy'
)

model(clf)
# Out:
# 0:	learn: 0.4986648	total: 69.9ms	remaining: 2.03s
# 1:	learn: 0.4342762	total: 73ms	remaining: 1.02s
# 2:	learn: 0.3778494	total: 74.1ms	remaining: 667ms
# 3:	learn: 0.3488791	total: 77.5ms	remaining: 504ms
# 4:	learn: 0.3297811	total: 86.3ms	remaining: 432ms
# 5:	learn: 0.3109115	total: 93.1ms	remaining: 372ms
# 6:	learn: 0.3001229	total: 96.9ms	remaining: 318ms
# 7:	learn: 0.2871741	total: 104ms	remaining: 285ms
# 8:	learn: 0.2792980	total: 111ms	remaining: 258ms
# 9:	learn: 0.2708689	total: 115ms	remaining: 230ms
# 10:	learn: 0.2652049	total: 128ms	remaining: 222ms
# 11:	learn: 0.2602596	total: 133ms	remaining: 200ms
# 12:	learn: 0.2518532	total: 139ms	remaining: 182ms
# 13:	learn: 0.2439697	total: 148ms	remaining: 169ms
# 14:	learn: 0.2402712	total: 151ms	remaining: 151ms
# 15:	learn: 0.2390979	total: 153ms	remaining: 133ms
# 16:	learn: 0.2309835	total: 156ms	remaining: 119ms
# 17:	learn: 0.2306513	total: 157ms	remaining: 105ms
# 18:	learn: 0.2303410	total: 158ms	remaining: 91.4ms
# 19:	learn: 0.2291627	total: 164ms	remaining: 82ms
# 20:	learn: 0.2287282	total: 167ms	remaining: 71.6ms
# 21:	learn: 0.2284528	total: 168ms	remaining: 61.1ms
# 22:	learn: 0.2281916	total: 185ms	remaining: 56.2ms
# 23:	learn: 0.2275095	total: 194ms	remaining: 48.5ms
# 24:	learn: 0.2271615	total: 195ms	remaining: 39ms
# 25:	learn: 0.2268848	total: 200ms	remaining: 30.8ms
# 26:	learn: 0.2250609	total: 201ms	remaining: 22.3ms
# 27:	learn: 0.2203912	total: 202ms	remaining: 14.4ms
# 28:	learn: 0.2201478	total: 203ms	remaining: 7.01ms
# 29:	learn: 0.2199545	total: 204ms	remaining: 0us
# Accuracy :  85.33%
# 0:	learn: 0.5024859	total: 681us	remaining: 19.8ms
# 1:	learn: 0.4376027	total: 1.81ms	remaining: 25.4ms
# 2:	learn: 0.4065804	total: 7.2ms	remaining: 64.8ms
# 3:	learn: 0.3698365	total: 8.32ms	remaining: 54.1ms
# 4:	learn: 0.3472891	total: 9.39ms	remaining: 47ms
# 5:	learn: 0.3340088	total: 10.9ms	remaining: 43.4ms
# 6:	learn: 0.3171069	total: 11.9ms	remaining: 39.1ms
# 7:	learn: 0.3019957	total: 17.3ms	remaining: 47.5ms
# 8:	learn: 0.2921141	total: 25.8ms	remaining: 60.1ms
# 9:	learn: 0.2819539	total: 29.8ms	remaining: 59.7ms
# 10:	learn: 0.2756469	total: 31ms	remaining: 53.5ms
# 11:	learn: 0.2713986	total: 32.1ms	remaining: 48.1ms
# 12:	learn: 0.2656736	total: 50.3ms	remaining: 65.8ms
# 13:	learn: 0.2578734	total: 51.4ms	remaining: 58.8ms
# 14:	learn: 0.2490881	total: 52.4ms	remaining: 52.4ms
# 15:	learn: 0.2440185	total: 53.4ms	remaining: 46.8ms
# 16:	learn: 0.2365881	total: 61.7ms	remaining: 47.2ms
# 17:	learn: 0.2334958	total: 62.7ms	remaining: 41.8ms
# 18:	learn: 0.2269295	total: 76ms	remaining: 44ms
# 19:	learn: 0.2248969	total: 77ms	remaining: 38.5ms
# 20:	learn: 0.2204860	total: 78.7ms	remaining: 33.7ms
# 21:	learn: 0.2183856	total: 79.7ms	remaining: 29ms
# 22:	learn: 0.2139868	total: 84.9ms	remaining: 25.8ms
# 23:	learn: 0.2121428	total: 89.6ms	remaining: 22.4ms
# 24:	learn: 0.2092403	total: 91.2ms	remaining: 18.2ms
# 25:	learn: 0.2066631	total: 98.1ms	remaining: 15.1ms
# 26:	learn: 0.2055836	total: 101ms	remaining: 11.3ms
# 27:	learn: 0.2049357	total: 105ms	remaining: 7.47ms
# 28:	learn: 0.2020834	total: 106ms	remaining: 3.64ms
# 29:	learn: 0.2004116	total: 107ms	remaining: 0us
# 0:	learn: 0.4952366	total: 607us	remaining: 17.6ms
# 1:	learn: 0.4310699	total: 1.86ms	remaining: 26.1ms
# 2:	learn: 0.3994671	total: 2.13ms	remaining: 19.2ms
# 3:	learn: 0.3629017	total: 4.45ms	remaining: 28.9ms
# 4:	learn: 0.3404855	total: 6.08ms	remaining: 30.4ms
# 5:	learn: 0.3251297	total: 20.1ms	remaining: 80.5ms
# 6:	learn: 0.3079901	total: 21.8ms	remaining: 71.6ms
# 7:	learn: 0.2912902	total: 24.2ms	remaining: 66.5ms
# 8:	learn: 0.2814971	total: 26.3ms	remaining: 61.3ms
# 9:	learn: 0.2720797	total: 29.2ms	remaining: 58.4ms
# 10:	learn: 0.2679830	total: 34.8ms	remaining: 60.2ms
# 11:	learn: 0.2638310	total: 38.3ms	remaining: 57.5ms
# 12:	learn: 0.2560965	total: 39.9ms	remaining: 52.1ms
# 13:	learn: 0.2492261	total: 42.3ms	remaining: 48.3ms
# 14:	learn: 0.2486146	total: 44.5ms	remaining: 44.5ms
# 15:	learn: 0.2379647	total: 47.4ms	remaining: 41.5ms
# 16:	learn: 0.2340911	total: 48.8ms	remaining: 37.3ms
# 17:	learn: 0.2337343	total: 51.6ms	remaining: 34.4ms
# 18:	learn: 0.2335121	total: 52.8ms	remaining: 30.5ms
# 19:	learn: 0.2325868	total: 55.4ms	remaining: 27.7ms
# 20:	learn: 0.2322834	total: 59.6ms	remaining: 25.5ms
# 21:	learn: 0.2255838	total: 62.2ms	remaining: 22.6ms
# 22:	learn: 0.2253980	total: 68.4ms	remaining: 20.8ms
# 23:	learn: 0.2213701	total: 70.5ms	remaining: 17.6ms
# 24:	learn: 0.2211692	total: 73.2ms	remaining: 14.6ms
# 25:	learn: 0.2203388	total: 88.6ms	remaining: 13.6ms
# 26:	learn: 0.2170547	total: 97.6ms	remaining: 10.8ms
# 27:	learn: 0.2167257	total: 100ms	remaining: 7.15ms
# 28:	learn: 0.2165237	total: 105ms	remaining: 3.62ms
# 29:	learn: 0.2147742	total: 108ms	remaining: 0us
# 0:	learn: 0.4992901	total: 610us	remaining: 17.7ms
# 1:	learn: 0.4322594	total: 3.89ms	remaining: 54.5ms
# 2:	learn: 0.3827182	total: 12ms	remaining: 108ms
# 3:	learn: 0.3554707	total: 20.7ms	remaining: 135ms
# 4:	learn: 0.3327096	total: 21.6ms	remaining: 108ms
# 5:	learn: 0.3139956	total: 22.4ms	remaining: 89.4ms
# 6:	learn: 0.3008367	total: 23.6ms	remaining: 77.7ms
# 7:	learn: 0.2944221	total: 24.9ms	remaining: 68.4ms
# 8:	learn: 0.2842922	total: 26.1ms	remaining: 60.8ms
# 9:	learn: 0.2779780	total: 26.8ms	remaining: 53.7ms
# 10:	learn: 0.2722150	total: 28ms	remaining: 48.3ms
# 11:	learn: 0.2676832	total: 31.8ms	remaining: 47.6ms
# 12:	learn: 0.2651379	total: 34.2ms	remaining: 44.7ms
# 13:	learn: 0.2647611	total: 34.9ms	remaining: 39.9ms
# 14:	learn: 0.2574009	total: 40.9ms	remaining: 40.9ms
# 15:	learn: 0.2569293	total: 42.2ms	remaining: 36.9ms
# 16:	learn: 0.2460690	total: 43ms	remaining: 32.8ms
# 17:	learn: 0.2453694	total: 43.8ms	remaining: 29.2ms
# 18:	learn: 0.2448960	total: 49.9ms	remaining: 28.9ms
# 19:	learn: 0.2445677	total: 50.7ms	remaining: 25.4ms
# 20:	learn: 0.2439768	total: 56.9ms	remaining: 24.4ms
# 21:	learn: 0.2421322	total: 58.1ms	remaining: 21.1ms
# 22:	learn: 0.2383593	total: 59.2ms	remaining: 18ms
# 23:	learn: 0.2373363	total: 60.3ms	remaining: 15.1ms
# 24:	learn: 0.2370752	total: 63.4ms	remaining: 12.7ms
# 25:	learn: 0.2365569	total: 63.9ms	remaining: 9.83ms
# 26:	learn: 0.2277243	total: 65.1ms	remaining: 7.24ms
# 27:	learn: 0.2274849	total: 66.8ms	remaining: 4.77ms
# 28:	learn: 0.2236795	total: 67.9ms	remaining: 2.34ms
# 29:	learn: 0.2222293	total: 76.4ms	remaining: 0us
# 0:	learn: 0.4948684	total: 617us	remaining: 17.9ms
# 1:	learn: 0.4265949	total: 1.69ms	remaining: 23.6ms
# 2:	learn: 0.3733905	total: 2.8ms	remaining: 25.2ms
# 3:	learn: 0.3429111	total: 11.4ms	remaining: 74ms
# 4:	learn: 0.3206489	total: 12.5ms	remaining: 62.5ms
# 5:	learn: 0.3016194	total: 13.2ms	remaining: 52.8ms
# 6:	learn: 0.2894661	total: 14.1ms	remaining: 46.4ms
# 7:	learn: 0.2823397	total: 19.6ms	remaining: 53.8ms
# 8:	learn: 0.2733607	total: 21ms	remaining: 49ms
# 9:	learn: 0.2616719	total: 22ms	remaining: 44.1ms
# 10:	learn: 0.2565353	total: 22.9ms	remaining: 39.6ms
# 11:	learn: 0.2537434	total: 24.1ms	remaining: 36.2ms
# 12:	learn: 0.2484920	total: 25ms	remaining: 32.6ms
# 13:	learn: 0.2440222	total: 25.7ms	remaining: 29.3ms
# 14:	learn: 0.2437809	total: 30.4ms	remaining: 30.4ms
# 15:	learn: 0.2407678	total: 31.5ms	remaining: 27.6ms
# 16:	learn: 0.2403769	total: 32.6ms	remaining: 24.9ms
# 17:	learn: 0.2401300	total: 33.3ms	remaining: 22.2ms
# 18:	learn: 0.2395510	total: 34.4ms	remaining: 19.9ms
# 19:	learn: 0.2391816	total: 35.3ms	remaining: 17.6ms
# 20:	learn: 0.2388443	total: 36.8ms	remaining: 15.8ms
# 21:	learn: 0.2372560	total: 37.9ms	remaining: 13.8ms
# 22:	learn: 0.2369582	total: 38.6ms	remaining: 11.8ms
# 23:	learn: 0.2325337	total: 41.7ms	remaining: 10.4ms
# 24:	learn: 0.2322454	total: 42.8ms	remaining: 8.56ms
# 25:	learn: 0.2225078	total: 44ms	remaining: 6.77ms
# 26:	learn: 0.2221936	total: 45.2ms	remaining: 5.02ms
# 27:	learn: 0.2202507	total: 46.2ms	remaining: 3.3ms
# 28:	learn: 0.2150967	total: 54.4ms	remaining: 1.88ms
# 29:	learn: 0.2130363	total: 58.6ms	remaining: 0us
# 0:	learn: 0.5002391	total: 660us	remaining: 19.1ms
# 1:	learn: 0.4333863	total: 1.59ms	remaining: 22.2ms
# 2:	learn: 0.3782213	total: 2.41ms	remaining: 21.7ms
# 3:	learn: 0.3450965	total: 3.19ms	remaining: 20.8ms
# 4:	learn: 0.3262621	total: 6.38ms	remaining: 31.9ms
# 5:	learn: 0.3084101	total: 11.3ms	remaining: 45.2ms
# 6:	learn: 0.2980283	total: 30.5ms	remaining: 100ms
# 7:	learn: 0.2911652	total: 31.3ms	remaining: 86ms
# 8:	learn: 0.2838616	total: 36.7ms	remaining: 85.6ms
# 9:	learn: 0.2709360	total: 37.5ms	remaining: 75ms
# 10:	learn: 0.2609445	total: 42.5ms	remaining: 73.4ms
# 11:	learn: 0.2558876	total: 49.4ms	remaining: 74ms
# 12:	learn: 0.2519783	total: 50.2ms	remaining: 65.6ms
# 13:	learn: 0.2462681	total: 60.8ms	remaining: 69.5ms
# 14:	learn: 0.2454911	total: 62.1ms	remaining: 62.1ms
# 15:	learn: 0.2446653	total: 64.5ms	remaining: 56.5ms
# 16:	learn: 0.2373128	total: 65.7ms	remaining: 50.2ms
# 17:	learn: 0.2370107	total: 66.2ms	remaining: 44.1ms
# 18:	learn: 0.2358932	total: 67.3ms	remaining: 38.9ms
# 19:	learn: 0.2355472	total: 80.3ms	remaining: 40.2ms
# 20:	learn: 0.2345058	total: 82ms	remaining: 35.1ms
# 21:	learn: 0.2293063	total: 85.5ms	remaining: 31.1ms
# 22:	learn: 0.2289801	total: 88.7ms	remaining: 27ms
# 23:	learn: 0.2287008	total: 91.2ms	remaining: 22.8ms
# 24:	learn: 0.2254136	total: 95.7ms	remaining: 19.1ms
# 25:	learn: 0.2247064	total: 106ms	remaining: 16.4ms
# 26:	learn: 0.2244294	total: 112ms	remaining: 12.5ms
# 27:	learn: 0.2241816	total: 116ms	remaining: 8.26ms
# 28:	learn: 0.2215813	total: 121ms	remaining: 4.17ms
# 29:	learn: 0.2156987	total: 128ms	remaining: 0us
# 0:	learn: 0.5029339	total: 496us	remaining: 14.4ms
# 1:	learn: 0.4352500	total: 1.28ms	remaining: 17.9ms
# 2:	learn: 0.4045349	total: 1.58ms	remaining: 14.2ms
# 3:	learn: 0.3720380	total: 2.37ms	remaining: 15.4ms
# 4:	learn: 0.3523877	total: 3.13ms	remaining: 15.6ms
# 5:	learn: 0.3340600	total: 3.86ms	remaining: 15.4ms
# 6:	learn: 0.3111204	total: 4.56ms	remaining: 15ms
# 7:	learn: 0.2970811	total: 9.4ms	remaining: 25.8ms
# 8:	learn: 0.2895284	total: 10.2ms	remaining: 23.9ms
# 9:	learn: 0.2816557	total: 11ms	remaining: 21.9ms
# 10:	learn: 0.2758309	total: 11.7ms	remaining: 20.3ms
# 11:	learn: 0.2709290	total: 12.5ms	remaining: 18.7ms
# 12:	learn: 0.2624212	total: 13.3ms	remaining: 17.3ms
# 13:	learn: 0.2582752	total: 14ms	remaining: 16ms
# 14:	learn: 0.2571757	total: 14.7ms	remaining: 14.7ms
# 15:	learn: 0.2546659	total: 15.4ms	remaining: 13.5ms
# 16:	learn: 0.2527487	total: 18.8ms	remaining: 14.4ms
# 17:	learn: 0.2477927	total: 19.6ms	remaining: 13.1ms
# 18:	learn: 0.2475419	total: 20.3ms	remaining: 11.8ms
# 19:	learn: 0.2439689	total: 21.1ms	remaining: 10.5ms
# 20:	learn: 0.2431547	total: 34.3ms	remaining: 14.7ms
# 21:	learn: 0.2370249	total: 35.9ms	remaining: 13.1ms
# 22:	learn: 0.2273400	total: 37.4ms	remaining: 11.4ms
# 23:	learn: 0.2238087	total: 39.4ms	remaining: 9.85ms
# 24:	learn: 0.2235871	total: 42ms	remaining: 8.4ms
# 25:	learn: 0.2233977	total: 43.1ms	remaining: 6.63ms
# 26:	learn: 0.2232148	total: 52.9ms	remaining: 5.87ms
# 27:	learn: 0.2230458	total: 54.4ms	remaining: 3.88ms
# 28:	learn: 0.2228924	total: 55.5ms	remaining: 1.92ms
# 29:	learn: 0.2227408	total: 57.8ms	remaining: 0us
# 0:	learn: 0.5003338	total: 661us	remaining: 19.2ms
# 1:	learn: 0.4294128	total: 4.09ms	remaining: 57.3ms
# 2:	learn: 0.3726684	total: 10.4ms	remaining: 93.7ms
# 3:	learn: 0.3472937	total: 11.2ms	remaining: 72.6ms
# 4:	learn: 0.3260186	total: 12ms	remaining: 59.8ms
# 5:	learn: 0.3084650	total: 12.7ms	remaining: 51ms
# 6:	learn: 0.2994606	total: 13.9ms	remaining: 45.8ms
# 7:	learn: 0.2868316	total: 14.8ms	remaining: 40.6ms
# 8:	learn: 0.2799087	total: 15.6ms	remaining: 36.3ms
# 9:	learn: 0.2726188	total: 16.5ms	remaining: 33ms
# 10:	learn: 0.2667038	total: 17.6ms	remaining: 30.3ms
# 11:	learn: 0.2618977	total: 18.4ms	remaining: 27.6ms
# 12:	learn: 0.2553115	total: 42.8ms	remaining: 56ms
# 13:	learn: 0.2486920	total: 54.3ms	remaining: 62ms
# 14:	learn: 0.2471811	total: 55.1ms	remaining: 55.1ms
# 15:	learn: 0.2398592	total: 55.9ms	remaining: 48.9ms
# 16:	learn: 0.2392843	total: 56.7ms	remaining: 43.4ms
# 17:	learn: 0.2388776	total: 57.2ms	remaining: 38.1ms
# 18:	learn: 0.2384134	total: 58.4ms	remaining: 33.8ms
# 19:	learn: 0.2297931	total: 59.8ms	remaining: 29.9ms
# 20:	learn: 0.2287149	total: 61.2ms	remaining: 26.2ms
# 21:	learn: 0.2281619	total: 63.8ms	remaining: 23.2ms
# 22:	learn: 0.2276916	total: 68.6ms	remaining: 20.9ms
# 23:	learn: 0.2267711	total: 71.4ms	remaining: 17.8ms
# 24:	learn: 0.2262578	total: 75.3ms	remaining: 15.1ms
# 25:	learn: 0.2259365	total: 76ms	remaining: 11.7ms
# 26:	learn: 0.2245037	total: 76.8ms	remaining: 8.53ms
# 27:	learn: 0.2241213	total: 77.6ms	remaining: 5.54ms
# 28:	learn: 0.2189775	total: 80.9ms	remaining: 2.79ms
# 29:	learn: 0.2182028	total: 81.6ms	remaining: 0us
# 0:	learn: 0.5000974	total: 627us	remaining: 18.2ms
# 1:	learn: 0.4314591	total: 1.63ms	remaining: 22.8ms
# 2:	learn: 0.3756649	total: 4.53ms	remaining: 40.8ms
# 3:	learn: 0.3454422	total: 6.27ms	remaining: 40.8ms
# 4:	learn: 0.3217956	total: 7.26ms	remaining: 36.3ms
# 5:	learn: 0.3030699	total: 19.4ms	remaining: 77.7ms
# 6:	learn: 0.2891446	total: 23.3ms	remaining: 76.5ms
# 7:	learn: 0.2776832	total: 25ms	remaining: 68.8ms
# 8:	learn: 0.2677524	total: 27.4ms	remaining: 64ms
# 9:	learn: 0.2625513	total: 34.9ms	remaining: 69.8ms
# 10:	learn: 0.2555707	total: 36.9ms	remaining: 63.7ms
# 11:	learn: 0.2487961	total: 43.1ms	remaining: 64.6ms
# 12:	learn: 0.2468051	total: 44.2ms	remaining: 57.8ms
# 13:	learn: 0.2392867	total: 68.6ms	remaining: 78.4ms
# 14:	learn: 0.2341439	total: 76.9ms	remaining: 76.9ms
# 15:	learn: 0.2283509	total: 80.2ms	remaining: 70.2ms
# 16:	learn: 0.2275817	total: 89.9ms	remaining: 68.7ms
# 17:	learn: 0.2269756	total: 97.2ms	remaining: 64.8ms
# 18:	learn: 0.2264910	total: 98.2ms	remaining: 56.9ms
# 19:	learn: 0.2261046	total: 102ms	remaining: 50.9ms
# 20:	learn: 0.2213907	total: 103ms	remaining: 44.1ms
# 21:	learn: 0.2211166	total: 109ms	remaining: 39.7ms
# 22:	learn: 0.2206710	total: 114ms	remaining: 34.8ms
# 23:	learn: 0.2202217	total: 121ms	remaining: 30.3ms
# 24:	learn: 0.2199511	total: 123ms	remaining: 24.7ms
# 25:	learn: 0.2195261	total: 125ms	remaining: 19.3ms
# 26:	learn: 0.2191436	total: 126ms	remaining: 14ms
# 27:	learn: 0.2182989	total: 135ms	remaining: 9.67ms
# 28:	learn: 0.2179183	total: 136ms	remaining: 4.7ms
# 29:	learn: 0.2127443	total: 141ms	remaining: 0us
# 0:	learn: 0.4974402	total: 531us	remaining: 15.4ms
# 1:	learn: 0.4225348	total: 3.42ms	remaining: 47.9ms
# 2:	learn: 0.3745896	total: 4.26ms	remaining: 38.4ms
# 3:	learn: 0.3463195	total: 5.18ms	remaining: 33.7ms
# 4:	learn: 0.3275974	total: 6.04ms	remaining: 30.2ms
# 5:	learn: 0.3096358	total: 6.85ms	remaining: 27.4ms
# 6:	learn: 0.2949146	total: 7.61ms	remaining: 25ms
# 7:	learn: 0.2861391	total: 12.5ms	remaining: 34.5ms
# 8:	learn: 0.2781482	total: 13.4ms	remaining: 31.3ms
# 9:	learn: 0.2678796	total: 14.2ms	remaining: 28.5ms
# 10:	learn: 0.2596780	total: 15ms	remaining: 26ms
# 11:	learn: 0.2570518	total: 15.8ms	remaining: 23.7ms
# 12:	learn: 0.2490694	total: 23.7ms	remaining: 31ms
# 13:	learn: 0.2412863	total: 24.6ms	remaining: 28.1ms
# 14:	learn: 0.2362362	total: 25.4ms	remaining: 25.4ms
# 15:	learn: 0.2285965	total: 26.2ms	remaining: 22.9ms
# 16:	learn: 0.2283968	total: 26.6ms	remaining: 20.4ms
# 17:	learn: 0.2276759	total: 31.7ms	remaining: 21.1ms
# 18:	learn: 0.2248500	total: 35.4ms	remaining: 20.5ms
# 19:	learn: 0.2245670	total: 38.1ms	remaining: 19.1ms
# 20:	learn: 0.2198301	total: 46.8ms	remaining: 20.1ms
# 21:	learn: 0.2194237	total: 49.6ms	remaining: 18ms
# 22:	learn: 0.2191871	total: 51.4ms	remaining: 15.7ms
# 23:	learn: 0.2189515	total: 53.9ms	remaining: 13.5ms
# 24:	learn: 0.2184487	total: 56.1ms	remaining: 11.2ms
# 25:	learn: 0.2166252	total: 58.4ms	remaining: 8.98ms
# 26:	learn: 0.2161153	total: 60.1ms	remaining: 6.68ms
# 27:	learn: 0.2158005	total: 62.9ms	remaining: 4.49ms
# 28:	learn: 0.2110021	total: 63.6ms	remaining: 2.19ms
# 29:	learn: 0.2107851	total: 65.3ms	remaining: 0us
# 0:	learn: 0.5044234	total: 628us	remaining: 18.2ms
# 1:	learn: 0.4323605	total: 3.84ms	remaining: 53.8ms
# 2:	learn: 0.3823263	total: 6.44ms	remaining: 58ms
# 3:	learn: 0.3529435	total: 12.8ms	remaining: 83.4ms
# 4:	learn: 0.3271236	total: 15.1ms	remaining: 75.7ms
# 5:	learn: 0.3060287	total: 17.6ms	remaining: 70.3ms
# 6:	learn: 0.2916408	total: 19.9ms	remaining: 65.3ms
# 7:	learn: 0.2820503	total: 22.7ms	remaining: 62.4ms
# 8:	learn: 0.2726907	total: 25.4ms	remaining: 59.4ms
# 9:	learn: 0.2629580	total: 26.5ms	remaining: 53.1ms
# 10:	learn: 0.2563991	total: 29.2ms	remaining: 50.5ms
# 11:	learn: 0.2490049	total: 31.4ms	remaining: 47.2ms
# 12:	learn: 0.2383207	total: 35.3ms	remaining: 46.2ms
# 13:	learn: 0.2305956	total: 37.5ms	remaining: 42.9ms
# 14:	learn: 0.2283627	total: 48.2ms	remaining: 48.2ms
# 15:	learn: 0.2254768	total: 50.8ms	remaining: 44.5ms
# 16:	learn: 0.2245600	total: 53.6ms	remaining: 41ms
# 17:	learn: 0.2241777	total: 56.9ms	remaining: 37.9ms
# 18:	learn: 0.2236644	total: 58.5ms	remaining: 33.9ms
# 19:	learn: 0.2233232	total: 65.3ms	remaining: 32.7ms
# 20:	learn: 0.2226052	total: 67.3ms	remaining: 28.8ms
# 21:	learn: 0.2222458	total: 70ms	remaining: 25.4ms
# 22:	learn: 0.2200138	total: 71.8ms	remaining: 21.9ms
# 23:	learn: 0.2171912	total: 73.5ms	remaining: 18.4ms
# 24:	learn: 0.2167620	total: 75.7ms	remaining: 15.1ms
# 25:	learn: 0.2162287	total: 77.9ms	remaining: 12ms
# 26:	learn: 0.2155592	total: 93ms	remaining: 10.3ms
# 27:	learn: 0.2153164	total: 94.3ms	remaining: 6.74ms
# 28:	learn: 0.2150867	total: 96.6ms	remaining: 3.33ms
# 29:	learn: 0.2084022	total: 99.3ms	remaining: 0us
# 0:	learn: 0.4948070	total: 596us	remaining: 17.3ms
# 1:	learn: 0.4232532	total: 3.16ms	remaining: 44.3ms
# 2:	learn: 0.3761824	total: 5.13ms	remaining: 46.2ms
# 3:	learn: 0.3495968	total: 7.77ms	remaining: 50.5ms
# 4:	learn: 0.3266517	total: 9.6ms	remaining: 48ms
# 5:	learn: 0.3066022	total: 12.3ms	remaining: 49.2ms
# 6:	learn: 0.2928106	total: 22.2ms	remaining: 72.8ms
# 7:	learn: 0.2866596	total: 24.6ms	remaining: 67.8ms
# 8:	learn: 0.2767225	total: 27ms	remaining: 63ms
# 9:	learn: 0.2670467	total: 32.3ms	remaining: 64.7ms
# 10:	learn: 0.2591990	total: 34.2ms	remaining: 59.1ms
# 11:	learn: 0.2537815	total: 36.8ms	remaining: 55.2ms
# 12:	learn: 0.2486462	total: 44.2ms	remaining: 57.8ms
# 13:	learn: 0.2388646	total: 45.6ms	remaining: 52.1ms
# 14:	learn: 0.2311297	total: 50.9ms	remaining: 50.9ms
# 15:	learn: 0.2304908	total: 53.1ms	remaining: 46.5ms
# 16:	learn: 0.2281918	total: 55.4ms	remaining: 42.4ms
# 17:	learn: 0.2260636	total: 62.1ms	remaining: 41.4ms
# 18:	learn: 0.2245952	total: 64.7ms	remaining: 37.5ms
# 19:	learn: 0.2228450	total: 67ms	remaining: 33.5ms
# 20:	learn: 0.2223127	total: 69.5ms	remaining: 29.8ms
# 21:	learn: 0.2215341	total: 76.4ms	remaining: 27.8ms
# 22:	learn: 0.2211401	total: 78.8ms	remaining: 24ms
# 23:	learn: 0.2208151	total: 83.1ms	remaining: 20.8ms
# 24:	learn: 0.2202740	total: 84.8ms	remaining: 17ms
# 25:	learn: 0.2197347	total: 87ms	remaining: 13.4ms
# 26:	learn: 0.2194558	total: 94.9ms	remaining: 10.5ms
# 27:	learn: 0.2191607	total: 97.2ms	remaining: 6.95ms
# 28:	learn: 0.2158175	total: 100ms	remaining: 3.46ms
# 29:	learn: 0.2155876	total: 103ms	remaining: 0us
# 0:	learn: 0.4955896	total: 621us	remaining: 18ms
# 1:	learn: 0.4276643	total: 3.33ms	remaining: 46.7ms
# 2:	learn: 0.3752088	total: 5.2ms	remaining: 46.8ms
# 3:	learn: 0.3460540	total: 7.53ms	remaining: 48.9ms
# 4:	learn: 0.3274743	total: 9.62ms	remaining: 48.1ms
# 5:	learn: 0.3110096	total: 12.8ms	remaining: 51.1ms
# 6:	learn: 0.2950814	total: 14.6ms	remaining: 48ms
# 7:	learn: 0.2886343	total: 16.9ms	remaining: 46.4ms
# 8:	learn: 0.2765352	total: 19ms	remaining: 44.3ms
# 9:	learn: 0.2658133	total: 21.1ms	remaining: 42.3ms
# 10:	learn: 0.2601835	total: 23.4ms	remaining: 40.4ms
# 11:	learn: 0.2541628	total: 25.6ms	remaining: 38.4ms
# 12:	learn: 0.2469121	total: 27.8ms	remaining: 36.4ms
# 13:	learn: 0.2409505	total: 29.7ms	remaining: 34ms
# 14:	learn: 0.2377485	total: 31.9ms	remaining: 31.9ms
# 15:	learn: 0.2375354	total: 33.1ms	remaining: 29ms
# 16:	learn: 0.2336665	total: 34.5ms	remaining: 26.4ms
# 17:	learn: 0.2333049	total: 36.8ms	remaining: 24.5ms
# 18:	learn: 0.2329621	total: 38.8ms	remaining: 22.5ms
# 19:	learn: 0.2324585	total: 40.9ms	remaining: 20.4ms
# 20:	learn: 0.2291412	total: 43.7ms	remaining: 18.7ms
# 21:	learn: 0.2249493	total: 46.7ms	remaining: 17ms
# 22:	learn: 0.2246134	total: 47.9ms	remaining: 14.6ms
# 23:	learn: 0.2241806	total: 52.3ms	remaining: 13.1ms
# 24:	learn: 0.2225261	total: 54.4ms	remaining: 10.9ms
# 25:	learn: 0.2221736	total: 59.3ms	remaining: 9.12ms
# 26:	learn: 0.2218988	total: 62.7ms	remaining: 6.96ms
# 27:	learn: 0.2217376	total: 65.4ms	remaining: 4.67ms
# 28:	learn: 0.2194915	total: 71ms	remaining: 2.45ms
# 29:	learn: 0.2143444	total: 73.3ms	remaining: 0us
# 0:	learn: 0.5000284	total: 520us	remaining: 15.1ms
# 1:	learn: 0.4309776	total: 1.77ms	remaining: 24.8ms
# 2:	learn: 0.3731841	total: 2.95ms	remaining: 26.6ms
# 3:	learn: 0.3449602	total: 4.11ms	remaining: 26.7ms
# 4:	learn: 0.3243353	total: 5.28ms	remaining: 26.4ms
# 5:	learn: 0.3060329	total: 6.37ms	remaining: 25.5ms
# 6:	learn: 0.2937840	total: 7.5ms	remaining: 24.6ms
# 7:	learn: 0.2868800	total: 8.65ms	remaining: 23.8ms
# 8:	learn: 0.2756448	total: 12.6ms	remaining: 29.4ms
# 9:	learn: 0.2681616	total: 19.7ms	remaining: 39.4ms
# 10:	learn: 0.2610971	total: 20.8ms	remaining: 35.9ms
# 11:	learn: 0.2579546	total: 21.8ms	remaining: 32.8ms
# 12:	learn: 0.2521152	total: 32.3ms	remaining: 42.2ms
# 13:	learn: 0.2469066	total: 33.4ms	remaining: 38.2ms
# 14:	learn: 0.2464858	total: 34.9ms	remaining: 34.9ms
# 15:	learn: 0.2416666	total: 36ms	remaining: 31.5ms
# 16:	learn: 0.2389195	total: 37.3ms	remaining: 28.5ms
# 17:	learn: 0.2269865	total: 38.5ms	remaining: 25.7ms
# 18:	learn: 0.2168746	total: 48.1ms	remaining: 27.8ms
# 19:	learn: 0.2125074	total: 53.2ms	remaining: 26.6ms
# 20:	learn: 0.2121399	total: 57.2ms	remaining: 24.5ms
# 21:	learn: 0.2119380	total: 67.1ms	remaining: 24.4ms
# 22:	learn: 0.2111177	total: 67.6ms	remaining: 20.6ms
# 23:	learn: 0.2094738	total: 68.8ms	remaining: 17.2ms
# 24:	learn: 0.2089154	total: 70.1ms	remaining: 14ms
# 25:	learn: 0.2072945	total: 76.7ms	remaining: 11.8ms
# 26:	learn: 0.2005090	total: 82.7ms	remaining: 9.19ms
# 27:	learn: 0.2002357	total: 84.8ms	remaining: 6.06ms
# 28:	learn: 0.1974937	total: 85.9ms	remaining: 2.96ms
# 29:	learn: 0.1970361	total: 95.5ms	remaining: 0us
# 0:	learn: 0.4975601	total: 954us	remaining: 27.7ms
# 1:	learn: 0.4281089	total: 5.18ms	remaining: 72.5ms
# 2:	learn: 0.3974258	total: 5.63ms	remaining: 50.7ms
# 3:	learn: 0.3607113	total: 10.1ms	remaining: 65.4ms
# 4:	learn: 0.3405091	total: 20.9ms	remaining: 104ms
# 5:	learn: 0.3273121	total: 26ms	remaining: 104ms
# 6:	learn: 0.3108588	total: 27.1ms	remaining: 89.1ms
# 7:	learn: 0.2964622	total: 33.7ms	remaining: 92.6ms
# 8:	learn: 0.2870204	total: 34.9ms	remaining: 81.5ms
# 9:	learn: 0.2782062	total: 41.1ms	remaining: 82.3ms
# 10:	learn: 0.2731587	total: 42.5ms	remaining: 73.4ms
# 11:	learn: 0.2663361	total: 43.5ms	remaining: 65.3ms
# 12:	learn: 0.2595455	total: 44.9ms	remaining: 58.7ms
# 13:	learn: 0.2540574	total: 45.8ms	remaining: 52.4ms
# 14:	learn: 0.2460052	total: 47.1ms	remaining: 47.1ms
# 15:	learn: 0.2427093	total: 52ms	remaining: 45.5ms
# 16:	learn: 0.2363841	total: 53.1ms	remaining: 40.6ms
# 17:	learn: 0.2357428	total: 59.4ms	remaining: 39.6ms
# 18:	learn: 0.2354532	total: 60ms	remaining: 34.7ms
# 19:	learn: 0.2350387	total: 61.1ms	remaining: 30.6ms
# 20:	learn: 0.2346883	total: 62.9ms	remaining: 26.9ms
# 21:	learn: 0.2344440	total: 64ms	remaining: 23.3ms
# 22:	learn: 0.2340885	total: 69.9ms	remaining: 21.3ms
# 23:	learn: 0.2338446	total: 71.4ms	remaining: 17.8ms
# 24:	learn: 0.2334457	total: 72.4ms	remaining: 14.5ms
# 25:	learn: 0.2299679	total: 79.5ms	remaining: 12.2ms
# 26:	learn: 0.2286215	total: 80.5ms	remaining: 8.94ms
# 27:	learn: 0.2220335	total: 81.5ms	remaining: 5.82ms
# 28:	learn: 0.2215576	total: 87.4ms	remaining: 3.01ms
# 29:	learn: 0.2213842	total: 90.2ms	remaining: 0us
# 0:	learn: 0.4993010	total: 600us	remaining: 17.4ms
# 1:	learn: 0.4311190	total: 2.26ms	remaining: 31.7ms
# 2:	learn: 0.3827352	total: 5.43ms	remaining: 48.9ms
# 3:	learn: 0.3507176	total: 12.7ms	remaining: 82.3ms
# 4:	learn: 0.3277569	total: 17.7ms	remaining: 88.5ms
# 5:	learn: 0.3061740	total: 23.3ms	remaining: 93.1ms
# 6:	learn: 0.2912981	total: 39.4ms	remaining: 129ms
# 7:	learn: 0.2839225	total: 40.5ms	remaining: 111ms
# 8:	learn: 0.2784559	total: 42ms	remaining: 97.9ms
# 9:	learn: 0.2688155	total: 43.2ms	remaining: 86.3ms
# 10:	learn: 0.2629464	total: 44.4ms	remaining: 76.7ms
# 11:	learn: 0.2572280	total: 45.6ms	remaining: 68.4ms
# 12:	learn: 0.2485767	total: 50.9ms	remaining: 66.5ms
# 13:	learn: 0.2401702	total: 51.6ms	remaining: 59ms
# 14:	learn: 0.2310429	total: 52.8ms	remaining: 52.8ms
# 15:	learn: 0.2307786	total: 53.2ms	remaining: 46.5ms
# 16:	learn: 0.2285470	total: 54.5ms	remaining: 41.7ms
# 17:	learn: 0.2282020	total: 55.3ms	remaining: 36.9ms
# 18:	learn: 0.2278179	total: 56.5ms	remaining: 32.7ms
# 19:	learn: 0.2257315	total: 57.7ms	remaining: 28.9ms
# 20:	learn: 0.2191102	total: 58.9ms	remaining: 25.2ms
# 21:	learn: 0.2186079	total: 60.1ms	remaining: 21.8ms
# 22:	learn: 0.2183232	total: 61.1ms	remaining: 18.6ms
# 23:	learn: 0.2179984	total: 62.2ms	remaining: 15.6ms
# 24:	learn: 0.2154725	total: 76.2ms	remaining: 15.2ms
# 25:	learn: 0.2152983	total: 77.3ms	remaining: 11.9ms
# 26:	learn: 0.2151324	total: 78.1ms	remaining: 8.68ms
# 27:	learn: 0.2099832	total: 80.4ms	remaining: 5.74ms
# 28:	learn: 0.2074767	total: 81.6ms	remaining: 2.81ms
# 29:	learn: 0.2071832	total: 82.8ms	remaining: 0us
# 0:	learn: 0.5026198	total: 640us	remaining: 18.6ms
# 1:	learn: 0.4335274	total: 1.72ms	remaining: 24.1ms
# 2:	learn: 0.3794356	total: 2.98ms	remaining: 26.8ms
# 3:	learn: 0.3512374	total: 13ms	remaining: 84.7ms
# 4:	learn: 0.3277111	total: 14.4ms	remaining: 72.3ms
# 5:	learn: 0.3086247	total: 15.4ms	remaining: 61.7ms
# 6:	learn: 0.2968371	total: 16.7ms	remaining: 54.8ms
# 7:	learn: 0.2888383	total: 17.8ms	remaining: 49.1ms
# 8:	learn: 0.2803404	total: 19.1ms	remaining: 44.5ms
# 9:	learn: 0.2703221	total: 20.2ms	remaining: 40.4ms
# 10:	learn: 0.2621825	total: 21.3ms	remaining: 36.8ms
# 11:	learn: 0.2587501	total: 22.6ms	remaining: 33.9ms
# 12:	learn: 0.2550855	total: 23.8ms	remaining: 31.2ms
# 13:	learn: 0.2501386	total: 36.8ms	remaining: 42.1ms
# 14:	learn: 0.2477623	total: 45ms	remaining: 45ms
# 15:	learn: 0.2453884	total: 46ms	remaining: 40.3ms
# 16:	learn: 0.2448749	total: 47.1ms	remaining: 36ms
# 17:	learn: 0.2353125	total: 48.2ms	remaining: 32.1ms
# 18:	learn: 0.2340080	total: 49.3ms	remaining: 28.6ms
# 19:	learn: 0.2285277	total: 50.5ms	remaining: 25.2ms
# 20:	learn: 0.2281957	total: 51.5ms	remaining: 22.1ms
# 21:	learn: 0.2278693	total: 80.4ms	remaining: 29.2ms
# 22:	learn: 0.2274435	total: 81.5ms	remaining: 24.8ms
# 23:	learn: 0.2272244	total: 89.5ms	remaining: 22.4ms
# 24:	learn: 0.2269489	total: 95.6ms	remaining: 19.1ms
# 25:	learn: 0.2267655	total: 96.4ms	remaining: 14.8ms
# 26:	learn: 0.2265083	total: 101ms	remaining: 11.3ms
# 27:	learn: 0.2262407	total: 102ms	remaining: 7.32ms
# 28:	learn: 0.2192692	total: 104ms	remaining: 3.57ms
# 29:	learn: 0.2134324	total: 111ms	remaining: 0us
# 0:	learn: 0.5077779	total: 6.73ms	remaining: 195ms
# 1:	learn: 0.4435334	total: 19ms	remaining: 266ms
# 2:	learn: 0.3963795	total: 29.3ms	remaining: 263ms
# 3:	learn: 0.3639918	total: 36.8ms	remaining: 239ms
# 4:	learn: 0.3406337	total: 37.9ms	remaining: 190ms
# 5:	learn: 0.3170455	total: 39ms	remaining: 156ms
# 6:	learn: 0.3066630	total: 51.3ms	remaining: 169ms
# 7:	learn: 0.2977750	total: 52.5ms	remaining: 144ms
# 8:	learn: 0.2898342	total: 60.3ms	remaining: 141ms
# 9:	learn: 0.2792872	total: 65.1ms	remaining: 130ms
# 10:	learn: 0.2705872	total: 81.8ms	remaining: 141ms
# 11:	learn: 0.2654485	total: 83.1ms	remaining: 125ms
# 12:	learn: 0.2552945	total: 89.4ms	remaining: 117ms
# 13:	learn: 0.2510418	total: 98.9ms	remaining: 113ms
# 14:	learn: 0.2412255	total: 107ms	remaining: 107ms
# 15:	learn: 0.2401309	total: 123ms	remaining: 107ms
# 16:	learn: 0.2396909	total: 129ms	remaining: 98.6ms
# 17:	learn: 0.2347729	total: 136ms	remaining: 90.4ms
# 18:	learn: 0.2342837	total: 137ms	remaining: 79.2ms
# 19:	learn: 0.2339321	total: 152ms	remaining: 75.8ms
# 20:	learn: 0.2335676	total: 153ms	remaining: 65.6ms
# 21:	learn: 0.2333366	total: 154ms	remaining: 56.1ms
# 22:	learn: 0.2330425	total: 161ms	remaining: 49.1ms
# 23:	learn: 0.2324882	total: 173ms	remaining: 43.3ms
# 24:	learn: 0.2321719	total: 175ms	remaining: 35.1ms
# 25:	learn: 0.2310221	total: 176ms	remaining: 27.2ms
# 26:	learn: 0.2307757	total: 185ms	remaining: 20.6ms
# 27:	learn: 0.2304439	total: 186ms	remaining: 13.3ms
# 28:	learn: 0.2302183	total: 187ms	remaining: 6.46ms
# 29:	learn: 0.2300088	total: 207ms	remaining: 0us
# 0:	learn: 0.5018193	total: 613us	remaining: 17.8ms
# 1:	learn: 0.4317210	total: 6.46ms	remaining: 90.4ms
# 2:	learn: 0.4014299	total: 11.3ms	remaining: 102ms
# 3:	learn: 0.3671441	total: 16.8ms	remaining: 109ms
# 4:	learn: 0.3443882	total: 23.3ms	remaining: 117ms
# 5:	learn: 0.3317617	total: 27.8ms	remaining: 111ms
# 6:	learn: 0.3127480	total: 38.2ms	remaining: 125ms
# 7:	learn: 0.2958609	total: 42.3ms	remaining: 116ms
# 8:	learn: 0.2831775	total: 50ms	remaining: 117ms
# 9:	learn: 0.2735198	total: 53.8ms	remaining: 108ms
# 10:	learn: 0.2687612	total: 58.4ms	remaining: 101ms
# 11:	learn: 0.2626133	total: 64.5ms	remaining: 96.8ms
# 12:	learn: 0.2567701	total: 71.8ms	remaining: 93.8ms
# 13:	learn: 0.2530388	total: 76.4ms	remaining: 87.3ms
# 14:	learn: 0.2526735	total: 80ms	remaining: 80ms
# 15:	learn: 0.2484774	total: 82.8ms	remaining: 72.5ms
# 16:	learn: 0.2456469	total: 89.9ms	remaining: 68.8ms
# 17:	learn: 0.2454094	total: 92.6ms	remaining: 61.7ms
# 18:	learn: 0.2428333	total: 108ms	remaining: 62.3ms
# 19:	learn: 0.2410964	total: 113ms	remaining: 56.6ms
# 20:	learn: 0.2406889	total: 115ms	remaining: 49.2ms
# 21:	learn: 0.2375560	total: 116ms	remaining: 42.2ms
# 22:	learn: 0.2373639	total: 121ms	remaining: 36.9ms
# 23:	learn: 0.2367178	total: 122ms	remaining: 30.6ms
# 24:	learn: 0.2358155	total: 125ms	remaining: 24.9ms
# 25:	learn: 0.2356349	total: 129ms	remaining: 19.8ms
# 26:	learn: 0.2353780	total: 131ms	remaining: 14.6ms
# 27:	learn: 0.2347887	total: 132ms	remaining: 9.46ms
# 28:	learn: 0.2333895	total: 140ms	remaining: 4.83ms
# 29:	learn: 0.2331442	total: 146ms	remaining: 0us
# 0:	learn: 0.5014125	total: 458us	remaining: 13.3ms
# 1:	learn: 0.4355708	total: 2.82ms	remaining: 39.5ms
# 2:	learn: 0.4040751	total: 11ms	remaining: 99.1ms
# 3:	learn: 0.3678770	total: 14.4ms	remaining: 93.7ms
# 4:	learn: 0.3403494	total: 17.3ms	remaining: 86.4ms
# 5:	learn: 0.3210254	total: 23.9ms	remaining: 95.4ms
# 6:	learn: 0.3070495	total: 29.9ms	remaining: 98.1ms
# 7:	learn: 0.2965264	total: 32ms	remaining: 87.9ms
# 8:	learn: 0.2909120	total: 33.3ms	remaining: 77.6ms
# 9:	learn: 0.2775992	total: 34.8ms	remaining: 69.6ms
# 10:	learn: 0.2719295	total: 38.6ms	remaining: 66.6ms
# 11:	learn: 0.2652863	total: 47.8ms	remaining: 71.8ms
# 12:	learn: 0.2608551	total: 50.6ms	remaining: 66.2ms
# 13:	learn: 0.2574115	total: 52.8ms	remaining: 60.4ms
# 14:	learn: 0.2535228	total: 55ms	remaining: 55ms
# 15:	learn: 0.2497072	total: 58.1ms	remaining: 50.8ms
# 16:	learn: 0.2487316	total: 61ms	remaining: 46.7ms
# 17:	learn: 0.2475137	total: 63.4ms	remaining: 42.3ms
# 18:	learn: 0.2468698	total: 66.4ms	remaining: 38.4ms
# 19:	learn: 0.2466590	total: 67.3ms	remaining: 33.7ms
# 20:	learn: 0.2464407	total: 69.2ms	remaining: 29.6ms
# 21:	learn: 0.2402578	total: 71.5ms	remaining: 26ms
# 22:	learn: 0.2386531	total: 74ms	remaining: 22.5ms
# 23:	learn: 0.2339893	total: 76.5ms	remaining: 19.1ms
# 24:	learn: 0.2322205	total: 78.7ms	remaining: 15.7ms
# 25:	learn: 0.2317282	total: 82.7ms	remaining: 12.7ms
# 26:	learn: 0.2280198	total: 85.2ms	remaining: 9.47ms
# 27:	learn: 0.2259555	total: 87.4ms	remaining: 6.24ms
# 28:	learn: 0.2231481	total: 89.7ms	remaining: 3.09ms
# 29:	learn: 0.2204500	total: 91.9ms	remaining: 0us
# 0:	learn: 0.4967281	total: 1.53ms	remaining: 44.3ms
# 1:	learn: 0.4276615	total: 9.47ms	remaining: 133ms
# 2:	learn: 0.3732105	total: 13.8ms	remaining: 124ms
# 3:	learn: 0.3462250	total: 21.8ms	remaining: 142ms
# 4:	learn: 0.3256749	total: 24.3ms	remaining: 122ms
# 5:	learn: 0.3013996	total: 25.8ms	remaining: 103ms
# 6:	learn: 0.2886356	total: 28.7ms	remaining: 94.4ms
# 7:	learn: 0.2790600	total: 30.5ms	remaining: 83.8ms
# 8:	learn: 0.2702423	total: 33.1ms	remaining: 77.2ms
# 9:	learn: 0.2584336	total: 37.9ms	remaining: 75.9ms
# 10:	learn: 0.2498473	total: 40.2ms	remaining: 69.4ms
# 11:	learn: 0.2413229	total: 46ms	remaining: 68.9ms
# 12:	learn: 0.2374618	total: 49.8ms	remaining: 65.1ms
# 13:	learn: 0.2324695	total: 51.7ms	remaining: 59.1ms
# 14:	learn: 0.2278230	total: 55.7ms	remaining: 55.7ms
# 15:	learn: 0.2245354	total: 57.1ms	remaining: 49.9ms
# 16:	learn: 0.2198691	total: 60.9ms	remaining: 46.5ms
# 17:	learn: 0.2139325	total: 64.2ms	remaining: 42.8ms
# 18:	learn: 0.2111473	total: 69.4ms	remaining: 40.2ms
# 19:	learn: 0.2062883	total: 71.8ms	remaining: 35.9ms
# 20:	learn: 0.2047348	total: 74.4ms	remaining: 31.9ms
# 21:	learn: 0.2007338	total: 76.9ms	remaining: 28ms
# 22:	learn: 0.2004802	total: 79.2ms	remaining: 24.1ms
# 23:	learn: 0.2002973	total: 81.4ms	remaining: 20.3ms
# 24:	learn: 0.2001057	total: 83.5ms	remaining: 16.7ms
# 25:	learn: 0.1999324	total: 86ms	remaining: 13.2ms
# 26:	learn: 0.1997348	total: 88.4ms	remaining: 9.82ms
# 27:	learn: 0.1995975	total: 91ms	remaining: 6.5ms
# 28:	learn: 0.1976910	total: 93.3ms	remaining: 3.22ms
# 29:	learn: 0.1956095	total: 95.9ms	remaining: 0us
# 0:	learn: 0.5008415	total: 485us	remaining: 14.1ms
# 1:	learn: 0.4335668	total: 4.33ms	remaining: 60.7ms
# 2:	learn: 0.4027625	total: 5.04ms	remaining: 45.4ms
# 3:	learn: 0.3689112	total: 6.09ms	remaining: 39.6ms
# 4:	learn: 0.3441144	total: 7.37ms	remaining: 36.8ms
# 5:	learn: 0.3304210	total: 8.39ms	remaining: 33.6ms
# 6:	learn: 0.3093758	total: 16.5ms	remaining: 54.2ms
# 7:	learn: 0.2947678	total: 23.1ms	remaining: 63.6ms
# 8:	learn: 0.2849186	total: 24.3ms	remaining: 56.8ms
# 9:	learn: 0.2771327	total: 25.4ms	remaining: 50.9ms
# 10:	learn: 0.2717744	total: 26.5ms	remaining: 45.8ms
# 11:	learn: 0.2672152	total: 27.5ms	remaining: 41.3ms
# 12:	learn: 0.2585982	total: 28.7ms	remaining: 37.6ms
# 13:	learn: 0.2514183	total: 34.8ms	remaining: 39.8ms
# 14:	learn: 0.2463421	total: 36.1ms	remaining: 36.1ms
# 15:	learn: 0.2428936	total: 37.6ms	remaining: 32.9ms
# 16:	learn: 0.2389908	total: 38.6ms	remaining: 29.5ms
# 17:	learn: 0.2362214	total: 40.3ms	remaining: 26.9ms
# 18:	learn: 0.2262779	total: 41.4ms	remaining: 24ms
# 19:	learn: 0.2228290	total: 44.4ms	remaining: 22.2ms
# 20:	learn: 0.2193684	total: 46.4ms	remaining: 19.9ms
# 21:	learn: 0.2157259	total: 48.2ms	remaining: 17.5ms
# 22:	learn: 0.2148167	total: 49.6ms	remaining: 15.1ms
# 23:	learn: 0.2128027	total: 50.7ms	remaining: 12.7ms
# 24:	learn: 0.2106858	total: 52.1ms	remaining: 10.4ms
# 25:	learn: 0.2083062	total: 55.4ms	remaining: 8.52ms
# 26:	learn: 0.2065825	total: 56.7ms	remaining: 6.29ms
# 27:	learn: 0.2012488	total: 62.8ms	remaining: 4.49ms
# 28:	learn: 0.2002025	total: 64ms	remaining: 2.21ms
# 29:	learn: 0.1957634	total: 65.2ms	remaining: 0us
# 0:	learn: 0.4924303	total: 659us	remaining: 19.1ms
# 1:	learn: 0.4221530	total: 2.53ms	remaining: 35.4ms
# 2:	learn: 0.3701053	total: 9.12ms	remaining: 82.1ms
# 3:	learn: 0.3383484	total: 10.4ms	remaining: 67.3ms
# 4:	learn: 0.3130160	total: 11.4ms	remaining: 57.2ms
# 5:	learn: 0.2965913	total: 12.5ms	remaining: 49.9ms
# 6:	learn: 0.2827346	total: 13.5ms	remaining: 44.4ms
# 7:	learn: 0.2711828	total: 14.5ms	remaining: 39.9ms
# 8:	learn: 0.2625089	total: 15.8ms	remaining: 36.9ms
# 9:	learn: 0.2553482	total: 22.9ms	remaining: 45.7ms
# 10:	learn: 0.2501000	total: 31.2ms	remaining: 54ms
# 11:	learn: 0.2443183	total: 33.5ms	remaining: 50.3ms
# 12:	learn: 0.2426663	total: 34.6ms	remaining: 45.2ms
# 13:	learn: 0.2362825	total: 35.6ms	remaining: 40.7ms
# 14:	learn: 0.2329561	total: 37.1ms	remaining: 37.1ms
# 15:	learn: 0.2272676	total: 39.3ms	remaining: 34.4ms
# 16:	learn: 0.2233546	total: 40ms	remaining: 30.6ms
# 17:	learn: 0.2226779	total: 41.1ms	remaining: 27.4ms
# 18:	learn: 0.2217100	total: 42.2ms	remaining: 24.4ms
# 19:	learn: 0.2161082	total: 43.3ms	remaining: 21.6ms
# 20:	learn: 0.2157245	total: 44.3ms	remaining: 19ms
# 21:	learn: 0.2070073	total: 47.3ms	remaining: 17.2ms
# 22:	learn: 0.2065792	total: 50.5ms	remaining: 15.4ms
# 23:	learn: 0.2063570	total: 52.1ms	remaining: 13ms
# 24:	learn: 0.2060186	total: 54.8ms	remaining: 11ms
# 25:	learn: 0.2057295	total: 61.5ms	remaining: 9.46ms
# 26:	learn: 0.2054654	total: 65.9ms	remaining: 7.32ms
# 27:	learn: 0.2005984	total: 67.7ms	remaining: 4.83ms
# 28:	learn: 0.2002313	total: 74.9ms	remaining: 2.58ms
# 29:	learn: 0.1999773	total: 77.8ms	remaining: 0us
# 0:	learn: 0.5010812	total: 639us	remaining: 18.5ms
# 1:	learn: 0.4270312	total: 13.3ms	remaining: 186ms
# 2:	learn: 0.3979773	total: 13.6ms	remaining: 123ms
# 3:	learn: 0.3637253	total: 21.6ms	remaining: 140ms
# 4:	learn: 0.3436203	total: 22.5ms	remaining: 112ms
# 5:	learn: 0.3201642	total: 23.7ms	remaining: 94.8ms
# 6:	learn: 0.3074781	total: 24.7ms	remaining: 81.3ms
# 7:	learn: 0.2914259	total: 25.7ms	remaining: 70.6ms
# 8:	learn: 0.2836954	total: 26.8ms	remaining: 62.6ms
# 9:	learn: 0.2755146	total: 28.8ms	remaining: 57.6ms
# 10:	learn: 0.2705652	total: 38ms	remaining: 65.7ms
# 11:	learn: 0.2671028	total: 39ms	remaining: 58.5ms
# 12:	learn: 0.2637993	total: 39.9ms	remaining: 52.2ms
# 13:	learn: 0.2614120	total: 48ms	remaining: 54.8ms
# 14:	learn: 0.2590367	total: 49.4ms	remaining: 49.4ms
# 15:	learn: 0.2583832	total: 65.4ms	remaining: 57.2ms
# 16:	learn: 0.2571742	total: 66.2ms	remaining: 50.6ms
# 17:	learn: 0.2508811	total: 67ms	remaining: 44.7ms
# 18:	learn: 0.2506823	total: 67.6ms	remaining: 39.1ms
# 19:	learn: 0.2474602	total: 73.4ms	remaining: 36.7ms
# 20:	learn: 0.2397180	total: 75ms	remaining: 32.1ms
# 21:	learn: 0.2387245	total: 76.1ms	remaining: 27.7ms
# 22:	learn: 0.2379880	total: 76.6ms	remaining: 23.3ms
# 23:	learn: 0.2377584	total: 77.2ms	remaining: 19.3ms
# 24:	learn: 0.2368353	total: 78.4ms	remaining: 15.7ms
# 25:	learn: 0.2340455	total: 79.5ms	remaining: 12.2ms
# 26:	learn: 0.2317150	total: 80.5ms	remaining: 8.95ms
# 27:	learn: 0.2308010	total: 81.6ms	remaining: 5.83ms
# 28:	learn: 0.2306509	total: 82.5ms	remaining: 2.84ms
# 29:	learn: 0.2258882	total: 83.3ms	remaining: 0us
# 0:	learn: 0.5014495	total: 580us	remaining: 16.8ms
# 1:	learn: 0.4260277	total: 1.82ms	remaining: 25.4ms
# 2:	learn: 0.3725211	total: 2.94ms	remaining: 26.4ms
# 3:	learn: 0.3445215	total: 8.94ms	remaining: 58.1ms
# 4:	learn: 0.3252418	total: 15.6ms	remaining: 78.1ms
# 5:	learn: 0.3062002	total: 16.7ms	remaining: 66.8ms
# 6:	learn: 0.2953806	total: 17.9ms	remaining: 58.9ms
# 7:	learn: 0.2883003	total: 18.9ms	remaining: 52.1ms
# 8:	learn: 0.2803810	total: 25.2ms	remaining: 58.7ms
# 9:	learn: 0.2704037	total: 26.1ms	remaining: 52.2ms
# 10:	learn: 0.2619038	total: 27.1ms	remaining: 46.8ms
# 11:	learn: 0.2552197	total: 28ms	remaining: 41.9ms
# 12:	learn: 0.2521257	total: 45.3ms	remaining: 59.3ms
# 13:	learn: 0.2479385	total: 46.4ms	remaining: 53.1ms
# 14:	learn: 0.2410890	total: 54.6ms	remaining: 54.6ms
# 15:	learn: 0.2408509	total: 55ms	remaining: 48.1ms
# 16:	learn: 0.2376857	total: 60.3ms	remaining: 46.1ms
# 17:	learn: 0.2371841	total: 65.4ms	remaining: 43.6ms
# 18:	learn: 0.2364493	total: 69.4ms	remaining: 40.2ms
# 19:	learn: 0.2358992	total: 70.4ms	remaining: 35.2ms
# 20:	learn: 0.2354298	total: 71.4ms	remaining: 30.6ms
# 21:	learn: 0.2350303	total: 75.4ms	remaining: 27.4ms
# 22:	learn: 0.2341162	total: 76.5ms	remaining: 23.3ms
# 23:	learn: 0.2337532	total: 81.6ms	remaining: 20.4ms
# 24:	learn: 0.2334438	total: 82.6ms	remaining: 16.5ms
# 25:	learn: 0.2323364	total: 89ms	remaining: 13.7ms
# 26:	learn: 0.2319263	total: 92.7ms	remaining: 10.3ms
# 27:	learn: 0.2311555	total: 118ms	remaining: 8.42ms
# 28:	learn: 0.2308969	total: 119ms	remaining: 4.09ms
# 29:	learn: 0.2252991	total: 119ms	remaining: 0us
# 0:	learn: 0.5036592	total: 5.66ms	remaining: 164ms
# 1:	learn: 0.4334102	total: 9.7ms	remaining: 136ms
# 2:	learn: 0.3813226	total: 22.5ms	remaining: 202ms
# 3:	learn: 0.3554560	total: 39.4ms	remaining: 256ms
# 4:	learn: 0.3328826	total: 45.2ms	remaining: 226ms
# 5:	learn: 0.3145912	total: 55.1ms	remaining: 220ms
# 6:	learn: 0.3046924	total: 69ms	remaining: 227ms
# 7:	learn: 0.2977240	total: 78.2ms	remaining: 215ms
# 8:	learn: 0.2896298	total: 111ms	remaining: 259ms
# 9:	learn: 0.2777676	total: 128ms	remaining: 255ms
# 10:	learn: 0.2712563	total: 140ms	remaining: 242ms
# 11:	learn: 0.2635880	total: 150ms	remaining: 225ms
# 12:	learn: 0.2552425	total: 161ms	remaining: 211ms
# 13:	learn: 0.2520411	total: 172ms	remaining: 197ms
# 14:	learn: 0.2490358	total: 199ms	remaining: 199ms
# 15:	learn: 0.2463878	total: 208ms	remaining: 182ms
# 16:	learn: 0.2460343	total: 218ms	remaining: 167ms
# 17:	learn: 0.2400236	total: 227ms	remaining: 151ms
# 18:	learn: 0.2396607	total: 231ms	remaining: 134ms
# 19:	learn: 0.2392872	total: 241ms	remaining: 120ms
# 20:	learn: 0.2320284	total: 242ms	remaining: 104ms
# 21:	learn: 0.2261930	total: 244ms	remaining: 88.7ms
# 22:	learn: 0.2250605	total: 247ms	remaining: 75ms
# 23:	learn: 0.2192427	total: 254ms	remaining: 63.5ms
# 24:	learn: 0.2147359	total: 256ms	remaining: 51.1ms
# 25:	learn: 0.2110622	total: 257ms	remaining: 39.6ms
# 26:	learn: 0.2067544	total: 259ms	remaining: 28.8ms
# 27:	learn: 0.2022309	total: 262ms	remaining: 18.7ms
# 28:	learn: 0.2019288	total: 270ms	remaining: 9.32ms
# 29:	learn: 0.2017274	total: 272ms	remaining: 0us
# 0:	learn: 0.4960957	total: 1.82ms	remaining: 52.9ms
# 1:	learn: 0.4323838	total: 5.36ms	remaining: 75ms
# 2:	learn: 0.3815415	total: 8.29ms	remaining: 74.7ms
# 3:	learn: 0.3511337	total: 25.5ms	remaining: 165ms
# 4:	learn: 0.3291962	total: 28.6ms	remaining: 143ms
# 5:	learn: 0.3047751	total: 38.7ms	remaining: 155ms
# 6:	learn: 0.2913370	total: 42.5ms	remaining: 140ms
# 7:	learn: 0.2805647	total: 49.1ms	remaining: 135ms
# 8:	learn: 0.2716217	total: 54.2ms	remaining: 127ms
# 9:	learn: 0.2599572	total: 59.9ms	remaining: 120ms
# 10:	learn: 0.2557233	total: 65.7ms	remaining: 114ms
# 11:	learn: 0.2508710	total: 75ms	remaining: 112ms
# 12:	learn: 0.2439732	total: 81.7ms	remaining: 107ms
# 13:	learn: 0.2339731	total: 86.4ms	remaining: 98.8ms
# 14:	learn: 0.2313052	total: 89.8ms	remaining: 89.8ms
# 15:	learn: 0.2300675	total: 94.9ms	remaining: 83ms
# 16:	learn: 0.2295308	total: 97.4ms	remaining: 74.5ms
# 17:	learn: 0.2247115	total: 105ms	remaining: 70ms
# 18:	learn: 0.2235460	total: 113ms	remaining: 65.2ms
# 19:	learn: 0.2227281	total: 115ms	remaining: 57.5ms
# 20:	learn: 0.2222441	total: 119ms	remaining: 51ms
# 21:	learn: 0.2200635	total: 124ms	remaining: 45.1ms
# 22:	learn: 0.2191579	total: 128ms	remaining: 39.1ms
# 23:	learn: 0.2185136	total: 135ms	remaining: 33.8ms
# 24:	learn: 0.2181872	total: 142ms	remaining: 28.3ms
# 25:	learn: 0.2141687	total: 148ms	remaining: 22.7ms
# 26:	learn: 0.2139526	total: 153ms	remaining: 17ms
# 27:	learn: 0.2127634	total: 156ms	remaining: 11.1ms
# 28:	learn: 0.2092248	total: 161ms	remaining: 5.57ms
# 29:	learn: 0.2024502	total: 167ms	remaining: 0us
# 0:	learn: 0.4993659	total: 1.35ms	remaining: 39.2ms
# 1:	learn: 0.4305065	total: 5.34ms	remaining: 74.8ms
# 2:	learn: 0.3819067	total: 11.3ms	remaining: 101ms
# 3:	learn: 0.3548399	total: 18ms	remaining: 117ms
# 4:	learn: 0.3300409	total: 23.6ms	remaining: 118ms
# 5:	learn: 0.3156704	total: 29.3ms	remaining: 117ms
# 6:	learn: 0.3050024	total: 32.1ms	remaining: 106ms
# 7:	learn: 0.2955302	total: 39ms	remaining: 107ms
# 8:	learn: 0.2891467	total: 45.4ms	remaining: 106ms
# 9:	learn: 0.2792416	total: 50.7ms	remaining: 101ms
# 10:	learn: 0.2709179	total: 53.4ms	remaining: 92.2ms
# 11:	learn: 0.2644140	total: 57ms	remaining: 85.6ms
# 12:	learn: 0.2553785	total: 63.8ms	remaining: 83.5ms
# 13:	learn: 0.2480508	total: 66ms	remaining: 75.4ms
# 14:	learn: 0.2408001	total: 68.8ms	remaining: 68.8ms
# 15:	learn: 0.2384877	total: 69.8ms	remaining: 61.1ms
# 16:	learn: 0.2380668	total: 82.9ms	remaining: 63.4ms
# 17:	learn: 0.2372820	total: 85.3ms	remaining: 56.9ms
# 18:	learn: 0.2338259	total: 91.5ms	remaining: 53ms
# 19:	learn: 0.2313192	total: 98.2ms	remaining: 49.1ms
# 20:	learn: 0.2310302	total: 103ms	remaining: 44ms
# 21:	learn: 0.2296422	total: 108ms	remaining: 39.4ms
# 22:	learn: 0.2240812	total: 113ms	remaining: 34.5ms
# 23:	learn: 0.2238966	total: 119ms	remaining: 29.7ms
# 24:	learn: 0.2233889	total: 125ms	remaining: 25ms
# 25:	learn: 0.2231982	total: 127ms	remaining: 19.6ms
# 26:	learn: 0.2159731	total: 131ms	remaining: 14.5ms
# 27:	learn: 0.2145376	total: 134ms	remaining: 9.54ms
# 28:	learn: 0.2100917	total: 139ms	remaining: 4.78ms
# 29:	learn: 0.2099200	total: 141ms	remaining: 0us
# 0:	learn: 0.4976124	total: 671us	remaining: 19.5ms
# 1:	learn: 0.4298544	total: 3.85ms	remaining: 53.9ms
# 2:	learn: 0.3754311	total: 9.19ms	remaining: 82.7ms
# 3:	learn: 0.3439748	total: 13.5ms	remaining: 87.5ms
# 4:	learn: 0.3236375	total: 18ms	remaining: 90.1ms
# 5:	learn: 0.3016881	total: 24.2ms	remaining: 96.6ms
# 6:	learn: 0.2916805	total: 28.3ms	remaining: 93.1ms
# 7:	learn: 0.2805426	total: 29.5ms	remaining: 81.2ms
# 8:	learn: 0.2742044	total: 34.1ms	remaining: 79.6ms
# 9:	learn: 0.2687616	total: 42.6ms	remaining: 85.2ms
# 10:	learn: 0.2626280	total: 44.1ms	remaining: 76.1ms
# 11:	learn: 0.2528506	total: 45.5ms	remaining: 68.3ms
# 12:	learn: 0.2485658	total: 47.7ms	remaining: 62.4ms
# 13:	learn: 0.2444337	total: 50.3ms	remaining: 57.5ms
# 14:	learn: 0.2408988	total: 56.4ms	remaining: 56.4ms
# 15:	learn: 0.2343510	total: 63.9ms	remaining: 55.9ms
# 16:	learn: 0.2316254	total: 70.7ms	remaining: 54ms
# 17:	learn: 0.2297341	total: 76.4ms	remaining: 50.9ms
# 18:	learn: 0.2284278	total: 79.1ms	remaining: 45.8ms
# 19:	learn: 0.2240054	total: 87.6ms	remaining: 43.8ms
# 20:	learn: 0.2236779	total: 91.1ms	remaining: 39ms
# 21:	learn: 0.2221112	total: 93.5ms	remaining: 34ms
# 22:	learn: 0.2216813	total: 95.7ms	remaining: 29.1ms
# 23:	learn: 0.2189408	total: 104ms	remaining: 25.9ms
# 24:	learn: 0.2187561	total: 105ms	remaining: 21ms
# 25:	learn: 0.2185846	total: 107ms	remaining: 16.4ms
# 26:	learn: 0.2183154	total: 109ms	remaining: 12.1ms
# 27:	learn: 0.2178499	total: 116ms	remaining: 8.32ms
# 28:	learn: 0.2164136	total: 118ms	remaining: 4.08ms
# 29:	learn: 0.2114565	total: 120ms	remaining: 0us
# 0:	learn: 0.5006211	total: 622us	remaining: 18.1ms
# 1:	learn: 0.4281453	total: 7.11ms	remaining: 99.6ms
# 2:	learn: 0.3799346	total: 20.5ms	remaining: 184ms
# 3:	learn: 0.3540958	total: 26.1ms	remaining: 169ms
# 4:	learn: 0.3301554	total: 29.7ms	remaining: 149ms
# 5:	learn: 0.3108560	total: 41.9ms	remaining: 168ms
# 6:	learn: 0.2980940	total: 49.5ms	remaining: 163ms
# 7:	learn: 0.2840681	total: 52.1ms	remaining: 143ms
# 8:	learn: 0.2759629	total: 56.7ms	remaining: 132ms
# 9:	learn: 0.2674463	total: 63.6ms	remaining: 127ms
# 10:	learn: 0.2606560	total: 69.5ms	remaining: 120ms
# 11:	learn: 0.2563970	total: 74.3ms	remaining: 111ms
# 12:	learn: 0.2505986	total: 87.3ms	remaining: 114ms
# 13:	learn: 0.2416481	total: 90.2ms	remaining: 103ms
# 14:	learn: 0.2395022	total: 95.9ms	remaining: 95.9ms
# 15:	learn: 0.2357111	total: 110ms	remaining: 96.1ms
# 16:	learn: 0.2352185	total: 118ms	remaining: 90.2ms
# 17:	learn: 0.2349360	total: 119ms	remaining: 79.3ms
# 18:	learn: 0.2336769	total: 122ms	remaining: 70.6ms
# 19:	learn: 0.2331503	total: 125ms	remaining: 62.5ms
# 20:	learn: 0.2326966	total: 129ms	remaining: 55.2ms
# 21:	learn: 0.2323468	total: 132ms	remaining: 48ms
# 22:	learn: 0.2319928	total: 134ms	remaining: 40.7ms
# 23:	learn: 0.2307397	total: 138ms	remaining: 34.5ms
# 24:	learn: 0.2231001	total: 139ms	remaining: 27.9ms
# 25:	learn: 0.2199018	total: 148ms	remaining: 22.8ms
# 26:	learn: 0.2145776	total: 150ms	remaining: 16.6ms
# 27:	learn: 0.2143203	total: 151ms	remaining: 10.8ms
# 28:	learn: 0.2124632	total: 159ms	remaining: 5.48ms
# 29:	learn: 0.2108959	total: 165ms	remaining: 0us
# 0:	learn: 0.5041934	total: 475us	remaining: 13.8ms
# 1:	learn: 0.4357139	total: 2.53ms	remaining: 35.5ms
# 2:	learn: 0.3809063	total: 3.35ms	remaining: 30.2ms
# 3:	learn: 0.3526392	total: 5.32ms	remaining: 34.6ms
# 4:	learn: 0.3339384	total: 9.78ms	remaining: 48.9ms
# 5:	learn: 0.3138685	total: 11.1ms	remaining: 44.5ms
# 6:	learn: 0.2981518	total: 12.7ms	remaining: 41.7ms
# 7:	learn: 0.2910857	total: 17.1ms	remaining: 47ms
# 8:	learn: 0.2810527	total: 20.8ms	remaining: 48.5ms
# 9:	learn: 0.2706197	total: 22ms	remaining: 44ms
# 10:	learn: 0.2665458	total: 25.3ms	remaining: 43.7ms
# 11:	learn: 0.2598610	total: 30ms	remaining: 45.1ms
# 12:	learn: 0.2527338	total: 31.2ms	remaining: 40.8ms
# 13:	learn: 0.2480456	total: 35.6ms	remaining: 40.6ms
# 14:	learn: 0.2446431	total: 39.4ms	remaining: 39.4ms
# 15:	learn: 0.2444531	total: 43.5ms	remaining: 38ms
# 16:	learn: 0.2398971	total: 46.6ms	remaining: 35.6ms
# 17:	learn: 0.2377234	total: 51.5ms	remaining: 34.3ms
# 18:	learn: 0.2363906	total: 56.2ms	remaining: 32.5ms
# 19:	learn: 0.2357973	total: 57.5ms	remaining: 28.7ms
# 20:	learn: 0.2306801	total: 61.5ms	remaining: 26.3ms
# 21:	learn: 0.2302234	total: 66.1ms	remaining: 24ms
# 22:	learn: 0.2297053	total: 67.4ms	remaining: 20.5ms
# 23:	learn: 0.2290908	total: 72.5ms	remaining: 18.1ms
# 24:	learn: 0.2287903	total: 73.7ms	remaining: 14.7ms
# 25:	learn: 0.2285414	total: 79.2ms	remaining: 12.2ms
# 26:	learn: 0.2282637	total: 80.4ms	remaining: 8.94ms
# 27:	learn: 0.2280169	total: 81.4ms	remaining: 5.82ms
# 28:	learn: 0.2268531	total: 82.4ms	remaining: 2.84ms
# 29:	learn: 0.2205251	total: 83.4ms	remaining: 0us
# Cross Validation Score :  92.91%
# ROC_AUC Score :  85.19%

# %%
model_evaluation(clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.81      0.84        89
#            1       0.83      0.89      0.86        95
#
#     accuracy                           0.85       184
#    macro avg       0.86      0.85      0.85       184
# weighted avg       0.85      0.85      0.85       184

# %% [markdown]
# Ensemble

# %%
from sklearn.ensemble import VotingClassifier

estimators=[('lr',classifier_lr),('svc',classifier_svc),('dt',classifier_dt),('rf',classifier_rf),('knn',classifier_knn),('xgb',xgb),('catboost',clf)]

ensemble = VotingClassifier(estimators, voting='hard')

ensemble.fit(x_train,y_train)
# Out:
# 0:	learn: 0.4986648	total: 787us	remaining: 22.8ms
# 1:	learn: 0.4342762	total: 2.94ms	remaining: 41.2ms
# 2:	learn: 0.3778494	total: 5.74ms	remaining: 51.6ms
# 3:	learn: 0.3488791	total: 7.73ms	remaining: 50.3ms
# 4:	learn: 0.3297811	total: 10.4ms	remaining: 52.2ms
# 5:	learn: 0.3109115	total: 12.8ms	remaining: 51.2ms
# 6:	learn: 0.3001229	total: 15.2ms	remaining: 49.8ms
# 7:	learn: 0.2871741	total: 17.6ms	remaining: 48.3ms
# 8:	learn: 0.2792980	total: 27.3ms	remaining: 63.7ms
# 9:	learn: 0.2708689	total: 29.9ms	remaining: 59.8ms
# 10:	learn: 0.2652049	total: 31.8ms	remaining: 54.9ms
# 11:	learn: 0.2602596	total: 34.2ms	remaining: 51.3ms
# 12:	learn: 0.2518532	total: 37.2ms	remaining: 48.6ms
# 13:	learn: 0.2439697	total: 38.8ms	remaining: 44.3ms
# 14:	learn: 0.2402712	total: 41.4ms	remaining: 41.4ms
# 15:	learn: 0.2390979	total: 43.7ms	remaining: 38.3ms
# 16:	learn: 0.2309835	total: 46ms	remaining: 35.2ms
# 17:	learn: 0.2306513	total: 48.2ms	remaining: 32.1ms
# 18:	learn: 0.2303410	total: 50.2ms	remaining: 29.1ms
# 19:	learn: 0.2291627	total: 52.6ms	remaining: 26.3ms
# 20:	learn: 0.2287282	total: 55.4ms	remaining: 23.8ms
# 21:	learn: 0.2284528	total: 58.3ms	remaining: 21.2ms
# 22:	learn: 0.2281916	total: 59.8ms	remaining: 18.2ms
# 23:	learn: 0.2275095	total: 61.3ms	remaining: 15.3ms
# 24:	learn: 0.2271615	total: 64.3ms	remaining: 12.9ms
# 25:	learn: 0.2268848	total: 67.2ms	remaining: 10.3ms
# 26:	learn: 0.2250609	total: 69.5ms	remaining: 7.72ms
# 27:	learn: 0.2203912	total: 72.6ms	remaining: 5.18ms
# 28:	learn: 0.2201478	total: 74.6ms	remaining: 2.57ms
# 29:	learn: 0.2199545	total: 76.4ms	remaining: 0us
# VotingClassifier(estimators=[('lr', LogisticRegression(C=10, random_state=0)),
#                              ('svc',
#                               SVC(C=0.1, kernel='linear', probability=True)),
#                              ('dt',
#                               DecisionTreeClassifier(max_depth=4,
#                                                      random_state=1000)),
#                              ('rf',
#                               RandomForestClassifier(max_depth=4,
#                                                      random_state=0)),
#                              ('knn',
#                               KNeighborsClassifier(leaf_size=1, n_neighbors=3,
#                                                    p=1)),
#                              ('xgb',
#                               XGBClassifier(base_score=None, booste...
#                                             learning_rate=None, max_bin=None,
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=None,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=None, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             random_state=None, ...)),
#                              ('catboost',
#                               <catboost.core.CatBoostClassifier object at 0x7e5116f946a0>)])

# %%
ensemble_pred = ensemble.predict(x_test)

# %%
class_names = ["0","1"]
report = classification_report(y_test, ensemble_pred, target_names=class_names)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.79      0.82        89
#            1       0.82      0.88      0.85        95
#
#     accuracy                           0.84       184
#    macro avg       0.84      0.84      0.84       184
# weighted avg       0.84      0.84      0.84       184
