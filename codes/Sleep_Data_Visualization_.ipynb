# %%
import pandas as pa
import numpy as np
import seaborn as sns

# %%
df=pa.read_csv('/content/sleep_preprocess.csv')

# %%
df.head()
# Out:
#    Gender  Occupation  BMI Category  systolic  diastolic  Age  Sleep Duration  \
# 0       0           0           0.0       126         83   27             6.1
# 1       0           1           1.0       125         80   28             6.2
# 2       0           1           1.0       125         80   28             6.2
# 3       0           2           2.0       140         90   28             5.9
# 4       0           2           2.0       140         90   28             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level  Heart Rate  \
# 0                 6                       42             6          77
# 1                 6                       60             8          75
# 2                 6                       60             8          75
# 3                 4                       30             8          78
# 4                 4                       30             8          78
#
#    Daily Steps  Sleep Disorder
# 0         4200               0
# 1        10000               0
# 2        10000               0
# 3         3000               1
# 4         3000               1

# %%
df.describe()
# Out:
#            Gender  Occupation  BMI Category    systolic   diastolic  \
# count  374.000000  374.000000    374.000000  374.000000  374.000000
# mean     0.494652    4.614973      0.715241  128.553476   84.649733
# std      0.500641    2.560033      0.684809    7.748118    6.161611
# min      0.000000    0.000000      0.000000  115.000000   75.000000
# 25%      0.000000    3.000000      0.000000  125.000000   80.000000
# 50%      0.000000    4.000000      1.000000  130.000000   85.000000
# 75%      1.000000    6.000000      1.000000  135.000000   90.000000
# max      1.000000   10.000000      2.500000  142.000000   95.000000
#
#               Age  Sleep Duration  Quality of Sleep  Physical Activity Level  \
# count  374.000000      374.000000        374.000000               374.000000
# mean    42.184492        7.132086          7.312834                59.171123
# std      8.673133        0.795657          1.196956                20.830804
# min     27.000000        5.800000          4.000000                30.000000
# 25%     35.250000        6.400000          6.000000                45.000000
# 50%     43.000000        7.200000          7.000000                60.000000
# 75%     50.000000        7.800000          8.000000                75.000000
# max     59.000000        8.500000          9.000000                90.000000
#
#        Stress Level  Heart Rate   Daily Steps  Sleep Disorder
# count    374.000000  374.000000    374.000000      374.000000
# mean       5.385027   69.965241   6816.844920        0.620321
# std        1.774526    3.567258   1617.915679        0.805620
# min        3.000000   65.000000   3000.000000        0.000000
# 25%        4.000000   68.000000   5600.000000        0.000000
# 50%        5.000000   70.000000   7000.000000        0.000000
# 75%        7.000000   72.000000   8000.000000        1.000000
# max        8.000000   78.000000  10000.000000        2.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Gender                   374 non-null    int64
#  1   Occupation               374 non-null    int64
#  2   BMI Category             374 non-null    float64
#  3   systolic                 374 non-null    int64
#  4   diastolic                374 non-null    int64
#  5   Age                      374 non-null    int64
#  6   Sleep Duration           374 non-null    float64
#  7   Quality of Sleep         374 non-null    int64
#  8   Physical Activity Level  374 non-null    int64
#  9   Stress Level             374 non-null    int64
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           374 non-null    int64
# dtypes: float64(2), int64(11)
# memory usage: 38.1 KB

# %%
df.dtypes
# Out:
# Gender                       int64
# Occupation                   int64
# BMI Category               float64
# systolic                     int64
# diastolic                    int64
# Age                          int64
# Sleep Duration             float64
# Quality of Sleep             int64
# Physical Activity Level      int64
# Stress Level                 int64
# Heart Rate                   int64
# Daily Steps                  int64
# Sleep Disorder               int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Gender                   374 non-null    int64
#  1   Occupation               374 non-null    int64
#  2   BMI Category             374 non-null    float64
#  3   systolic                 374 non-null    int64
#  4   diastolic                374 non-null    int64
#  5   Age                      374 non-null    int64
#  6   Sleep Duration           374 non-null    float64
#  7   Quality of Sleep         374 non-null    int64
#  8   Physical Activity Level  374 non-null    int64
#  9   Stress Level             374 non-null    int64
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           374 non-null    int64
# dtypes: float64(2), int64(11)
# memory usage: 38.1 KB

# %%
import matplotlib.pyplot as plt

corr = df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True)
plt.title('Heatmap of Correlations')
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a scatterplot matrix
sns.pairplot(df)
plt.show()

# %%
for i in df.columns.values:
    Q1,Q3 = np.percentile(df[i],[25,75])
    IQR = Q3 - Q1
    lf = Q1 - (1.5*IQR)
    hf = Q3 + (1.5*IQR)
    df.loc[df[i]>hf, i] = hf
    df.loc[df[i]<lf, i] = lf

# %%
fig = plt.figure(figsize =(10, 7))
# Creating plot
plt.boxplot(df)
plt.show()

# %%
# Create a histogram plot for each column
df.hist(figsize=(10, 10))
plt.show()
